# %%
# %%writefile kmeans_cpu_serial.c
# /*
#   kmeans_cpu_serial.c
#   Serial (single-thread) K-means with per-iteration profiling suitable for comparison
#   with the CUDA version. Outputs:
#     - labels_cpu_serial.csv
#     - centroids_cpu_serial.csv
#     - profile_cpu_serial.csv
#     - meta_cpu_serial.txt
#
#   Build:
#     gcc -O3 -march=native kmeans_cpu_serial.c -o kmeans_cpu_serial -lm
#
#   Run:
#     ./kmeans_cpu_serial N D K max_iter tol init_method verbose profile_csv
#
#   Defaults:
#     N=20000, D=16, K=10, max_iter=200, tol=1e-4, init_method=1 (kmeans++), verbose=1
# */
#
# #define _POSIX_C_SOURCE 200809L
# #include <stdio.h>
# #include <stdlib.h>
# #include <math.h>
# #include <string.h>
# #include <time.h>
# #include <unistd.h>
#
# #ifndef M_PI
# #define M_PI 3.14159265358979323846
# #endif
#
# static double now_ms() {
#     struct timespec ts;
#     clock_gettime(CLOCK_MONOTONIC, &ts);
#     return ts.tv_sec*1000.0 + ts.tv_nsec/1.0e6;
# }
#
# /* xorshift64* RNG (same as other binaries) */
# static unsigned long long rng_state = 88172645463325252ULL;
# static inline unsigned long long xorshift64star() {
#     unsigned long long x = rng_state;
#     x ^= x >> 12; x ^= x << 25; x ^= x >> 27;
#     rng_state = x;
#     return x * 2685821657736338717ULL;
# }
# static inline double drand01() {
#     return (xorshift64star() >> 11) * (1.0/9007199254740992.0);
# }
#
# /* Synthetic data generator (same logic as CUDA and OpenMP versions) */
# static void generate_synthetic(double *data, int N, int D, int K) {
#     double *centers = (double*)malloc((size_t)K*D*sizeof(double));
#     for (int k=0;k<K;++k)
#         for (int d=0; d<D; ++d)
#             centers[k*D + d] = (drand01()*2.0 - 1.0) * 10.0;
#
#     for (int i=0;i<N;++i) {
#         srand(123);
#         int c = rand() % K;
#         for (int d=0; d<D; ++d) {
#             double u1 = drand01(), u2 = drand01();
#             double r = sqrt(-2.0 * log(fmax(u1,1e-12)));
#             double z = r * cos(2*M_PI*u2);
#             double scale = 1.0 + 0.5 * drand01();
#             data[i*D + d] = centers[c*D + d] + z * scale;
#         }
#     }
#     free(centers);
# }
#
# /* squared distance */
# static inline double sqdist(const double *p, const double *c, int D) {
#     double s = 0.0;
#     for (int d=0; d<D; ++d) {
#         double diff = p[d] - c[d];
#         s += diff*diff;
#     }
#     return s;
# }
#
# /* kmeans++ init (same as GPU host path) */
# static void init_kmeanspp(const double *data, double *centroids, int N, int D, int K) {
#     int first = (int)(drand01() * N);
#     for (int d=0; d<D; ++d) centroids[0*D + d] = data[first*D + d];
#
#     double *dist2 = (double*)malloc((size_t)N*sizeof(double));
#     for (int i=0;i<N;++i) dist2[i] = sqdist(&data[i*D], &centroids[0*D], D);
#
#     for (int k=1;k<K;++k) {
#         double sum = 0.0;
#         for (int i=0;i<N;++i) sum += dist2[i];
#         double r = drand01() * sum;
#         double csum = 0.0;
#         int chosen = N-1;
#         for (int i=0;i<N;++i) {
#             csum += dist2[i];
#             if (csum >= r) { chosen = i; break; }
#         }
#         for (int d=0; d<D; ++d) centroids[k*D + d] = data[chosen*D + d];
#
#         for (int i=0;i<N;++i) {
#             double v = sqdist(&data[i*D], &centroids[k*D], D);
#             if (v < dist2[i]) dist2[i] = v;
#         }
#     }
#     free(dist2);
# }
#
# /* Save helpers (distinct filenames to avoid clashes) */
# static void save_labels(const char *path, const int *labels, int N) {
#     FILE *f = fopen(path, "w"); if (!f) { perror(path); return; }
#     for (int i=0;i<N;++i) fprintf(f, "%d\n", labels[i]);
#     fclose(f);
# }
# static void save_centroids(const char *path, const double *centroids, int K, int D) {
#     FILE *f = fopen(path, "w"); if (!f) { perror(path); return; }
#     for (int k=0;k<K;++k) {
#         for (int d=0; d<D; ++d) {
#             fprintf(f, "%.8f", centroids[k*D + d]);
#             if (d < D-1) fputc(',', f);
#         }
#         fputc('\n', f);
#     }
#     fclose(f);
# }
#
# /* Serial K-means with per-iteration profiling and CSV output */
# static void kmeans_run_serial(
#     const double *data, double *centroids, int *labels,
#     int N, int D, int K, int max_iter, double tol, int verbose, const char *profile_csv,
#     double *out_inertia, int *out_iters)
# {
#     FILE *pf = NULL;
#     if (profile_csv && strlen(profile_csv) > 0) {
#         pf = fopen(profile_csv, "w");
#         if (pf) fprintf(pf, "iter,t_assign_ms,t_update_ms,t_inertia_ms,t_iter_ms\n");
#     }
#
#     double inertia = 0.0;
#     int iters = 0;
#     for (int iter=0; iter<max_iter; ++iter) {
#         double t_iter0 = now_ms();
#
#         /* assignment + accumulation (serial) */
#         double t0 = now_ms();
#         // zero accumulators
#         double *sums = (double*)calloc((size_t)K*D, sizeof(double));
#         int *counts = (int*)calloc((size_t)K, sizeof(int));
#
#         for (int i=0;i<N;++i) {
#             const double *p = &data[i*D];
#             int best = 0;
#             double bestd = sqdist(p, &centroids[0*D], D);
#             for (int k=1;k<K;++k) {
#                 double d = sqdist(p, &centroids[k*D], D);
#                 if (d < bestd) { bestd = d; best = k; }
#             }
#             labels[i] = best;
#             counts[best] += 1;
#             for (int d=0; d<D; ++d) sums[best*D + d] += p[d];
#         }
#         double t_assign = now_ms() - t0;
#
#         /* update centroids */
#         t0 = now_ms();
#         double movement = 0.0;
#         for (int k=0;k<K;++k) {
#             if (counts[k] > 0) {
#                 for (int d=0; d<D; ++d) {
#                     double newc = sums[k*D + d] / (double)counts[k];
#                     double diff = centroids[k*D + d] - newc;
#                     movement += diff*diff;
#                     centroids[k*D + d] = newc;
#                 }
#             } else {
#                 /* keep old if empty */
#             }
#         }
#         double t_update = now_ms() - t0;
#
#         /* inertia */
#         t0 = now_ms();
#         inertia = 0.0;
#         for (int i=0;i<N;++i) {
#             int lbl = labels[i];
#             inertia += sqdist(&data[i*D], &centroids[lbl*D], D);
#         }
#         double t_inertia = now_ms() - t0;
#
#         double t_iter = now_ms() - t_iter0;
#         if (pf) fprintf(pf, "%d,%.6f,%.6f,%.6f,%.6f\n", iter+1, t_assign, t_update, t_inertia, t_iter);
#
#         if (verbose) {
#             printf("Iter %3d | assign=%.3f ms update=%.3f ms inertia=%.3f ms | total=%.3f ms | move=%.6g\n",
#                    iter+1, t_assign, t_update, t_inertia, t_iter, movement);
#         }
#
#         free(sums); free(counts);
#
#         iters = iter + 1;
#         if (movement < tol) {
#             if (verbose) printf("Converged (movement %.6g <= tol %.6g)\n", movement, tol);
#             break;
#         }
#     }
#
#     if (pf) fclose(pf);
#     *out_inertia = inertia;
#     *out_iters = iters;
# }
#
# int main(int argc, char** argv) {
#     int N = 20000, D = 16, K = 10, max_iter = 200, verbose = 1;
#     double tol = 1e-4;
#     int init_method = 1;
#     const char *profile_csv = "profile_cpu_serial.csv";
#
#     if (argc >= 2) N = atoi(argv[1]);
#     if (argc >= 3) D = atoi(argv[2]);
#     if (argc >= 4) K = atoi(argv[3]);
#     if (argc >= 5) max_iter = atoi(argv[4]);
#     if (argc >= 6) tol = atof(argv[5]);
#     if (argc >= 7) init_method = atoi(argv[6]);
#     if (argc >= 8) verbose = atoi(argv[7]);
#     if (argc >= 9) profile_csv = argv[8];
#
#     rng_state = 88172645463325252ULL;
#
#     printf("Serial K-means CPU: N=%d D=%d K=%d max_iter=%d tol=%g init=%s\n",
#            N, D, K, max_iter, tol, init_method ? "kmeans++" : "random");
#
#     long nprocs = (long)sysconf(_SC_NPROCESSORS_ONLN);
#     printf("Host reports CPU cores available: %ld\n", nprocs);
#
#     /* allocate host data */
#     double *h_data = (double*)malloc((size_t)N*D*sizeof(double));
#     double *h_centroids = (double*)malloc((size_t)K*D*sizeof(double));
#     int *h_labels = (int*)malloc((size_t)N*sizeof(int));
#     if (!h_data || !h_centroids || !h_labels) { fprintf(stderr, "alloc failed\n"); return 1; }
#
#     printf("Generating synthetic data on host...\n");
#     generate_synthetic(h_data, N, D, K);
#
#     if (init_method) {
#         printf("Initializing centroids with kmeans++\n");
#         init_kmeanspp(h_data, h_centroids, N, D, K);
#     } else {
#         // random init simple fallback
#         for (int k=0;k<K;++k) {
#             int idx = (int)(drand01() * N);
#             for (int d=0; d<D; ++d) h_centroids[k*D + d] = h_data[idx*D + d];
#         }
#     }
#
#     double t0 = now_ms();
#     double inertia = 0.0; int iters = 0;
#     kmeans_run_serial(h_data, h_centroids, h_labels, N, D, K, max_iter, tol, verbose, profile_csv, &inertia, &iters);
#     double t1 = now_ms();
#
#     printf("Serial K-means finished: iters=%d inertia=%.6g total_time=%.3f ms\n", iters, inertia, t1-t0);
#
#     /* save outputs with distinct names to avoid clashes */
#     save_labels("labels_cpu_serial.csv", h_labels, N);
#     save_centroids("centroids_cpu_serial.csv", h_centroids, K, D);
#
#     /* write meta file */
#     FILE *mf = fopen("meta_cpu_serial.txt", "w");
#     if (mf) { fprintf(mf, "N %d\nD %d\nK %d\n", N, D, K); fclose(mf); }
#
#     printf("Saved labels_cpu_serial.csv, centroids_cpu_serial.csv, profile_cpu_serial.csv, meta_cpu_serial.txt\n");
#
#     free(h_data); free(h_centroids); free(h_labels);
#     return 0;
# }
# Out:
# Writing kmeans_cpu_serial.c

# %%
# !gcc -O3 -march=native kmeans_cpu_serial.c -o kmeans_cpu_serial -lm
# !ls -lh kmeans_cpu_serial
# Out:
# -rwxr-xr-x 1 root root 21K Nov 29 22:08 kmeans_cpu_serial

# %%
import subprocess
import re
import csv
import time

# Ns to test for CPU serial
Ns = [100, 500, 1000, 5000, 10000, 20000, 50000, 100000, 200000, 300000, 500000, 1000000, 2000000]   # add more if you want

D = 16
K = 10
max_iter = 200
tol = "1e-4"
init_method = 1    # kmeans++
verbose = 0        # TURN THIS OFF FOR SPEED

results = []

print("Running CPU Serial K-means benchmarks...\n")

for N in Ns:
    print(f"▶ Running N = {N:,} ...")

    cmd = ["./kmeans_cpu_serial",
           str(N), str(D), str(K),
           str(max_iter), tol,
           str(init_method), str(verbose),
           f"profile_cpu_serial_{N}.csv"]

    # run & capture text output
    start = time.time()
    out = subprocess.check_output(cmd, universal_newlines=True)
    end = time.time()

    # Extract "total_time=xxx ms"
    match = re.search(r"total_time=([\d.]+)\s*ms", out)
    total_ms = float(match.group(1)) if match else None

    results.append((N, total_ms))
    print(f"   ✔ Done: {total_ms} ms\n")

print("🎉 All CPU serial runs complete!\n")

# Save summary to CSV
with open("runtime_cpu_serial.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["N", "time_ms"])
    writer.writerows(results)

print("Saved results to runtime_cpu_serial.csv\n")

# Print summary
print("===== SUMMARY (CPU SERIAL) =====")
for N, t in results:
    print(f"N={N:>10} → {t:.3f} ms")
# Out:
# Running CPU Serial K-means benchmarks...
#
# ▶ Running N = 100 ...
#    ✔ Done: 0.296 ms
#
# ▶ Running N = 500 ...
#    ✔ Done: 1.841 ms
#
# ▶ Running N = 1,000 ...
#    ✔ Done: 3.171 ms
#
# ▶ Running N = 5,000 ...
#    ✔ Done: 106.82 ms
#
# ▶ Running N = 10,000 ...
#    ✔ Done: 180.07 ms
#
# ▶ Running N = 20,000 ...
#    ✔ Done: 379.131 ms
#
# ▶ Running N = 50,000 ...
#    ✔ Done: 1167.851 ms
#
# ▶ Running N = 100,000 ...
#    ✔ Done: 3600.485 ms
#
# ▶ Running N = 200,000 ...
#    ✔ Done: 5760.269 ms
#
# ▶ Running N = 300,000 ...
#    ✔ Done: 10413.472 ms
#
# ▶ Running N = 500,000 ...
#    ✔ Done: 15306.132 ms
#
# ▶ Running N = 1,000,000 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-906084146.py in <cell line: 0>()
#      29     # run & capture text output
#      30     start = time.time()
# ---> 31     out = subprocess.check_output(cmd, universal_newlines=True)
#      32     end = time.time()
#      33
#
# /usr/lib/python3.12/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     464         kwargs['input'] = empty
#     465
# --> 466     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467                **kwargs).stdout
#     468
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1194                 self._stdin_write(input)
#    1195             elif self.stdout:
# -> 1196                 stdout = self.stdout.read()
#    1197                 self.stdout.close()
#    1198             elif self.stderr:
#
# KeyboardInterrupt:

# %%
# %%writefile kmeans_cuda_prof.cu
# // kmeans_cuda_prof.cu
# // GPU K-means with CUDA C (uses <cuda.h>), per-iteration timing, and CSV profiling.
# // Outputs: labels_cuda.csv, centroids_cuda.csv, profile_cuda.csv, meta_cuda.txt
# // Build:   nvcc -O3 -arch=sm_75 kmeans_cuda_prof.cu -o kmeans_cuda_prof
# // Run:     ./kmeans_cuda_prof 20000 16 10 200 1e-4 256 1 profile_cuda.csv
#
# #include <cstdio>
# #include <cstdlib>
# #include <cmath>
# #include <cstring>
# #include <string>
# #include <cuda.h>
# #include <cuda_runtime.h>
#
# #ifndef M_PI
# #define M_PI 3.14159265358979323846
# #endif
#
# // ----------------- Error check -----------------
# #define CUDA_CHECK(e) do{ \
#   cudaError_t err=(e); \
#   if(err!=cudaSuccess){ \
#     fprintf(stderr,"CUDA error %s:%d: %s\n", __FILE__, __LINE__, cudaGetErrorString(err)); \
#     exit(1);} \
# }while(0)
#
# // ----------------- Simple timer -----------------
# static double now_ms() {
#   struct timespec ts;
#   clock_gettime(CLOCK_MONOTONIC, &ts);
#   return ts.tv_sec*1000.0 + ts.tv_nsec/1.0e6;
# }
#
# // ----------------- RNG (xorshift64*) -----------------
# static unsigned long long rng_state = 88172645463325252ULL;
# static inline unsigned long long xorshift64star() {
#   unsigned long long x = rng_state;
#   x ^= x >> 12; x ^= x << 25; x ^= x >> 27;
#   rng_state = x;
#   return x * 2685821657736338717ULL;
# }
# static inline double drand01() {
#   return (xorshift64star() >> 11) * (1.0/9007199254740992.0);
# }
#
# // ----------------- Data generation (host) -----------------
# static void generate_synthetic(double *data, int N, int D, int K) {
#   double *centers = (double*)malloc((size_t)K*D*sizeof(double));
#   for(int k=0;k<K;++k) for(int d=0;d<D;++d)
#     centers[k*D+d] = (drand01()*2.0 - 1.0) * 10.0;
#
#   for(int i=0;i<N;++i){
#     srand(123);
#     int c = rand() % K;
#     for(int d=0; d<D; ++d){
#       double u1=drand01(), u2=drand01();
#       double r = sqrt(-2.0 * log(fmax(u1,1e-12)));
#       double z = r * cos(2*M_PI*u2);
#       double scale = 1.0 + 0.5*drand01();
#       data[i*D + d] = centers[c*D + d] + z*scale;
#     }
#   }
#   free(centers);
# }
#
# // ----------------- KMeans++ init (host) -----------------
# static inline double sqdist_host(const double* p, const double* c, int D){
#   double s=0.0; for(int d=0; d<D; ++d){ double df=p[d]-c[d]; s+=df*df; } return s;
# }
#
# static void init_kmeanspp(const double *data, double *centroids, int N, int D, int K) {
#   int first = (int)(drand01() * N);
#   memcpy(&centroids[0], &data[first*D], (size_t)D*sizeof(double));
#   double *dist2 = (double*)malloc((size_t)N*sizeof(double));
#   for(int i=0;i<N;++i) dist2[i] = sqdist_host(&data[i*D], &centroids[0], D);
#
#   for(int k=1;k<K;++k){
#     double sum=0.0; for(int i=0;i<N;++i) sum += dist2[i];
#     double r=drand01()*sum, csum=0.0; int chosen=N-1;
#     for(int i=0;i<N;++i){ csum += dist2[i]; if(csum>=r){chosen=i; break;} }
#     memcpy(&centroids[k*D], &data[chosen*D], (size_t)D*sizeof(double));
#     for(int i=0;i<N;++i){
#       double v = sqdist_host(&data[i*D], &centroids[k*D], D);
#       if(v<dist2[i]) dist2[i]=v;
#     }
#   }
#   free(dist2);
# }
#
# // ----------------- Device info -----------------
# static void print_device_info() {
#   int dev=0; CUDA_CHECK(cudaGetDevice(&dev));
#   cudaDeviceProp p; CUDA_CHECK(cudaGetDeviceProperties(&p, dev));
#   printf("Device %d: %s\n", dev, p.name);
#   printf("  CC %d.%d  SMs=%d  warpSize=%d  maxThreadsPerBlock=%d  sharedMemPerBlock=%zu KB\n",
#          p.major, p.minor, p.multiProcessorCount, p.warpSize, p.maxThreadsPerBlock,
#          p.sharedMemPerBlock/1024);
#   printf("  memory: %.1f GB global, %.1f MB const\n",
#          p.totalGlobalMem/1e9, p.totalConstMem/1e6);
# }
#
# // ----------------- Kernels -----------------
# // assign + accumulate sums and counts + record dist2
# // data: N x D (row-major), centroids: K x D
# // sums: K x D (double), counts: K (int), labels: N
# // dist2_out: per-point squared distance to nearest centroid
# __global__ void assign_accumulate_kernel(
#   const double* __restrict__ data,
#   const double* __restrict__ centroids,
#   int N, int D, int K,
#   int* __restrict__ labels,
#   double* __restrict__ sums,
#   int* __restrict__ counts,
#   double* __restrict__ dist2_out,
#   int* __restrict__ thread_map_sample // size >= sampleN*3, stores [i,blockIdx.x,threadIdx.x] etc.
# ){
#   int i = blockIdx.x * blockDim.x + threadIdx.x;
#   if (i >= N) return;
#
#   // record a small sample of (point_i, block, thread)
#   if (thread_map_sample && i < 16) {
#     int base = i*3;
#     thread_map_sample[base+0] = i;
#     thread_map_sample[base+1] = blockIdx.x;
#     thread_map_sample[base+2] = threadIdx.x;
#   }
#
#   // find nearest centroid
#   int best_k = 0;
#   double bestd = 0.0;
#   // distance to centroid 0
#   {
#     double s=0.0;
#     const double* p = &data[i*D];
#     const double* c = &centroids[0];
#     for(int d=0; d<D; ++d){ double df=p[d]-c[d]; s+=df*df; }
#     bestd = s;
#   }
#   for(int k=1;k<K;++k){
#     double s=0.0;
#     const double* p = &data[i*D];
#     const double* c = &centroids[k*D];
#     for(int d=0; d<D; ++d){ double df=p[d]-c[d]; s+=df*df; }
#     if (s < bestd){ bestd=s; best_k=k; }
#   }
#   labels[i] = best_k;
#   dist2_out[i] = bestd;
#
#   // accumulate sums & counts (atomics on double require CC>=6.0)
#   atomicAdd(&counts[best_k], 1);
#   const double* p = &data[i*D];
#   for(int d=0; d<D; ++d){
#     atomicAdd(&sums[best_k*D + d], p[d]);
#   }
# }
#
# // ----------------- Save helpers -----------------
# static void save_labels(const char* path, const int* labels, int N) {
#   FILE* f=fopen(path,"w"); if(!f){perror("labels_cuda.csv");return;}
#   for(int i=0;i<N;++i) fprintf(f,"%d\n", labels[i]);
#   fclose(f);
# }
# static void save_centroids(const char* path, const double* C, int K, int D) {
#   FILE* f=fopen(path,"w"); if(!f){perror("centroids_cuda.csv");return;}
#   for(int k=0;k<K;++k){
#     for(int d=0; d<D; ++d){
#       fprintf(f,"%.8f", C[k*D+d]);
#       if(d<D-1) fputc(',', f);
#     }
#     fputc('\n', f);
#   }
#   fclose(f);
# }
#
# // ----------------- Main -----------------
# int main(int argc, char** argv){
#   // Args: N D K max_iter tol block_size verbose profile_csv
#   int    N = 20000;
#   int    D = 16;
#   int    K = 10;
#   int    max_iter = 200;
#   double tol = 1e-4;
#   int    block_size = 256;
#   int    verbose = 1;
#   const char* profile_csv = "profile_cuda.csv";
#
#   if(argc>=2)  N = atoi(argv[1]);
#   if(argc>=3)  D = atoi(argv[2]);
#   if(argc>=4)  K = atoi(argv[3]);
#   if(argc>=5)  max_iter = atoi(argv[4]);
#   if(argc>=6)  tol = atof(argv[5]);
#   if(argc>=7)  block_size = atoi(argv[6]);
#   if(argc>=8)  verbose = atoi(argv[7]);
#   if(argc>=9)  profile_csv = argv[8];
#
#   rng_state = 88172645463325252ULL;
#
#   print_device_info();
#   printf("K-means CUDA: N=%d D=%d K=%d max_iter=%d tol=%g block=%d verbose=%d\n",
#          N,D,K,max_iter,tol,block_size,verbose);
#
#   // Host alloc
#   size_t szX = (size_t)N*D*sizeof(double);
#   size_t szC = (size_t)K*D*sizeof(double);
#   size_t szL = (size_t)N*sizeof(int);
#   double *h_data=(double*)malloc(szX);
#   double *h_centroids=(double*)malloc(szC);
#   int    *h_labels=(int*)malloc(szL);
#   if(!h_data||!h_centroids||!h_labels){ fprintf(stderr,"Host alloc failed\n"); return 1; }
#
#   // Generate & init
#   printf("Generating synthetic data on host...\n");
#   generate_synthetic(h_data, N, D, K);
#   printf("Init (kmeans++) on host...\n");
#   init_kmeanspp(h_data, h_centroids, N, D, K);
#
#   // Device alloc
#   double *d_data=nullptr, *d_centroids=nullptr, *d_sums=nullptr, *d_dist2=nullptr;
#   int *d_counts=nullptr, *d_labels=nullptr, *d_threadmap=nullptr;
#   CUDA_CHECK(cudaMalloc(&d_data, szX));
#   CUDA_CHECK(cudaMalloc(&d_centroids, szC));
#   CUDA_CHECK(cudaMalloc(&d_labels, szL));
#   CUDA_CHECK(cudaMalloc(&d_sums, szC));
#   CUDA_CHECK(cudaMalloc(&d_counts, K*sizeof(int)));
#   CUDA_CHECK(cudaMalloc(&d_dist2, N*sizeof(double)));
#   CUDA_CHECK(cudaMalloc(&d_threadmap, 16*3*sizeof(int))); // sample for first 16 points
#
#   // Copy data to device
#   CUDA_CHECK(cudaMemcpy(d_data, h_data, szX, cudaMemcpyHostToDevice));
#   CUDA_CHECK(cudaMemcpy(d_centroids, h_centroids, szC, cudaMemcpyHostToDevice));
#
#   // grid config
#   int grid = (N + block_size - 1) / block_size;
#   printf("Launch config: grid=%d blocks, block=%d threads  (total threads %d)\n",
#          grid, block_size, grid*block_size);
#
#   // CSV profile
#   FILE* pf = fopen(profile_csv, "w");
#   if(pf){ fprintf(pf, "iter,t_kernel_ms,t_update_ms,t_inertia_ms,t_iter_ms\n"); }
#
#   // events for kernel timing
#   cudaEvent_t evA, evB; CUDA_CHECK(cudaEventCreate(&evA)); CUDA_CHECK(cudaEventCreate(&evB));
#
#   double total_start = now_ms();
#   double inertia = 0.0;
#
#   for(int iter=0; iter<max_iter; ++iter){
#     double t_iter0 = now_ms();
#
#     // zero accumulators
#     CUDA_CHECK(cudaMemset(d_sums, 0, szC));
#     CUDA_CHECK(cudaMemset(d_counts, 0, K*sizeof(int)));
#
#     // ---- assignment + accumulate (kernel) ----
#     CUDA_CHECK(cudaEventRecord(evA));
#     assign_accumulate_kernel<<<grid, block_size>>>(
#       d_data, d_centroids, N, D, K, d_labels, d_sums, d_counts, d_dist2, d_threadmap
#     );
#     CUDA_CHECK(cudaEventRecord(evB));
#     CUDA_CHECK(cudaEventSynchronize(evB));
#     float t_kernel_ms=0.0f; CUDA_CHECK(cudaEventElapsedTime(&t_kernel_ms, evA, evB));
#
#     // ---- update centroids (host) ----
#     double t0 = now_ms();
#     // copy sums + counts back
#     double *h_sums=(double*)malloc(szC);
#     int *h_counts=(int*)malloc(K*sizeof(int));
#     CUDA_CHECK(cudaMemcpy(h_sums, d_sums, szC, cudaMemcpyDeviceToHost));
#     CUDA_CHECK(cudaMemcpy(h_counts, d_counts, K*sizeof(int), cudaMemcpyDeviceToHost));
#
#     double movement=0.0;
#     for(int k=0;k<K;++k){
#       if(h_counts[k]>0){
#         for(int d=0; d<D; ++d){
#           double newc = h_sums[k*D + d] / (double)h_counts[k];
#           double diff = h_centroids[k*D + d] - newc;
#           movement += diff*diff;
#           h_centroids[k*D + d] = newc;
#         }
#       } else {
#         // keep old centroid if empty
#       }
#     }
#     // copy new centroids to device
#     CUDA_CHECK(cudaMemcpy(d_centroids, h_centroids, szC, cudaMemcpyHostToDevice));
#     double t_update_ms = now_ms() - t0;
#
#     // ---- inertia (host sum over dist2) ----
#     t0 = now_ms();
#     // We already computed nearest-centroid distances in kernel into d_dist2.
#     double *h_d2 = (double*)malloc(N*sizeof(double));
#     CUDA_CHECK(cudaMemcpy(h_d2, d_dist2, N*sizeof(double), cudaMemcpyDeviceToHost));
#     inertia = 0.0;
#     for(int i=0;i<N;++i) inertia += h_d2[i];
#     free(h_d2);
#     double t_inertia_ms = now_ms() - t0;
#
#     double t_iter_ms = now_ms() - t_iter0;
#
#     if(verbose){
#       if(iter==0){
#         int thrmap[16*3]={0};
#         CUDA_CHECK(cudaMemcpy(thrmap, d_threadmap, 16*3*sizeof(int), cudaMemcpyDeviceToHost));
#         printf("Thread map sample (first up to 16 points): [i, blockIdx.x, threadIdx.x]\n");
#         int sample = (N<16)?N:16;
#         for(int j=0;j<sample;++j){
#           printf("  i=%d  block=%d  thread=%d\n", thrmap[j*3+0], thrmap[j*3+1], thrmap[j*3+2]);
#         }
#       }
#       printf("Iter %3d | kernel(assign+accum)=%.3f ms, update=%.3f ms, inertia(sum)=%.3f ms | total=%.3f ms | move=%.6g\n",
#              iter+1, t_kernel_ms, t_update_ms, t_inertia_ms, t_iter_ms, movement);
#     }
#     if(pf){ fprintf(pf, "%d,%.6f,%.6f,%.6f,%.6f\n",
#                     iter+1, t_kernel_ms, t_update_ms, t_inertia_ms, t_iter_ms); fflush(pf); }
#
#     free(h_sums); free(h_counts);
#
#     if(movement < tol){
#       if(verbose) printf("Converged (movement %.6g <= tol %.6g)\n", movement, tol);
#       break;
#     }
#   }
#
#   double total_ms = now_ms() - total_start;
#   printf("Total wall time: %.2f ms  (includes H2D/D2H where applicable)\n", total_ms);
#
#   // Copy final labels back and save outputs
#   CUDA_CHECK(cudaMemcpy(h_labels, d_labels, szL, cudaMemcpyDeviceToHost));
#   save_labels("labels_cuda.csv", h_labels, N);
#   save_centroids("centroids_cuda.csv", h_centroids, K, D);
#
#   // meta for viz
#   FILE* meta=fopen("meta_cuda.txt","w");
#   if(meta){ fprintf(meta, "N %d\nD %d\nK %d\n", N,D,K); fclose(meta); }
#   if(pf){ fclose(pf); printf("Profile saved to %s\n", profile_csv); }
#
#   // cleanup
#   cudaEventDestroy(evA); cudaEventDestroy(evB);
#   cudaFree(d_data); cudaFree(d_centroids); cudaFree(d_labels);
#   cudaFree(d_sums); cudaFree(d_counts); cudaFree(d_dist2); cudaFree(d_threadmap);
#   free(h_data); free(h_centroids); free(h_labels);
#   return 0;
# }
# Out:
# Writing kmeans_cuda_prof.cu

# %%
# !nvcc -O3 -arch=sm_75 kmeans_cuda_prof.cu -o kmeans_cuda_prof
# !ls -lh kmeans_cuda_prof
# Out:
# -rwxr-xr-x 1 root root 1000K Nov 29 22:08 kmeans_cuda_prof

# %%
import subprocess
import re
import csv
import time

# Ns you want to test
Ns = [100, 500, 1000, 5000, 10000, 20000, 50000, 100000, 200000, 300000, 500000, 1000000, 2000000]

D = 16
K = 10
max_iter = 200
tol = "1e-4"
block = 256
verbose = 0   # KEEP THIS 0 FOR SPEED

results = []

print("Running K-means benchmarks...\n")

for N in Ns:
    print(f"▶ Running N = {N:,} ...")

    # build command
    cmd = ["./kmeans_cuda_prof",
           str(N), str(D), str(K),
           str(max_iter), tol,
           str(block), str(verbose),
           f"profile_{N}.csv"]

    # run & capture output
    start = time.time()
    out = subprocess.check_output(cmd, universal_newlines=True)
    end = time.time()

    # find "Total wall time: xxx ms"
    match = re.search(r"Total wall time:\s*([\d.]+)\s*ms", out)
    total_ms = float(match.group(1)) if match else None

    results.append((N, total_ms))
    print(f"   ✔ Done: {total_ms} ms\n")

print("🎉 All runs complete!\n")

# Save results to a CSV
with open("runtime_results.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["N", "time_ms"])
    writer.writerows(results)

print("Saved results to runtime_results.csv\n")

# Also print a summary
print("===== SUMMARY =====")
for N, t in results:
    print(f"N={N:>10} → {t:.3f} ms")
# Out:
# Running K-means benchmarks...
#
# ▶ Running N = 100 ...
#    ✔ Done: 0.79 ms
#
# ▶ Running N = 500 ...
#    ✔ Done: 4.5 ms
#
# ▶ Running N = 1,000 ...
#    ✔ Done: 9.04 ms
#
# ▶ Running N = 5,000 ...
#    ✔ Done: 62.22 ms
#
# ▶ Running N = 10,000 ...
#    ✔ Done: 48.74 ms
#
# ▶ Running N = 20,000 ...
#    ✔ Done: 80.0 ms
#
# ▶ Running N = 50,000 ...
#    ✔ Done: 201.36 ms
#
# ▶ Running N = 100,000 ...
#    ✔ Done: 255.15 ms
#
# ▶ Running N = 200,000 ...
#    ✔ Done: 401.4 ms
#
# ▶ Running N = 300,000 ...
#    ✔ Done: 577.26 ms
#
# ▶ Running N = 500,000 ...
#    ✔ Done: 926.25 ms
#
# ▶ Running N = 1,000,000 ...
#    ✔ Done: 1936.34 ms
#
# ▶ Running N = 2,000,000 ...
#    ✔ Done: 3547.97 ms
#
# 🎉 All runs complete!
#
# Saved results to runtime_results.csv
#
# ===== SUMMARY =====
# N=       100 → 0.790 ms
# N=       500 → 4.500 ms
# N=      1000 → 9.040 ms
# N=      5000 → 62.220 ms
# N=     10000 → 48.740 ms
# N=     20000 → 80.000 ms
# N=     50000 → 201.360 ms
# N=    100000 → 255.150 ms
# N=    200000 → 401.400 ms
# N=    300000 → 577.260 ms
# N=    500000 → 926.250 ms
# N=   1000000 → 1936.340 ms
# N=   2000000 → 3547.970 ms

# %%
# !nvcc -O3 -arch=sm_75 kmeans_cuda_prof.cu -o kmeans_cuda_prof
# !gcc -O3 -march=native kmeans_cpu_serial.c -o kmeans_cpu_serial -lm
# Out:
# cc1: fatal error: kmeans_cpu_serial.c: No such file or directory
# compilation terminated.

# %%
# ============================================================
# N-WISE GPU + CPU MONITORING FOR CUDA K-MEANS
# Saves: nwise_monitoring.csv
# ============================================================

import subprocess
import time
import pandas as pd
import psutil
import threading

# ------------------------------------------------------------
# 1. CONFIGURE YOUR N VALUES
# ------------------------------------------------------------
N_values = [100, 500, 1000, 5000, 10000, 20000, 50000, 100000, 200000, 300000, 500000, 1000000, 2000000]

# ------------------------------------------------------------
# 2. FUNCTION TO RUN GPU MONITOR
# ------------------------------------------------------------
gpu_records = []
monitor_running = True

def gpu_monitor():
    global monitor_running
    while monitor_running:
        # Run nvidia-smi once
        result = subprocess.run(
            ["nvidia-smi", "--query-gpu=utilization.gpu,utilization.memory,memory.used,power.draw",
             "--format=csv,noheader,nounits"],
            stdout=subprocess.PIPE, text=True
        )
        gpu = result.stdout.strip().split(", ")
        if len(gpu) == 4:
            gpu_records.append({
                "util_gpu": float(gpu[0]),
                "util_mem": float(gpu[1]),
                "mem_used": float(gpu[2]),
                "power": float(gpu[3]),
            })
        time.sleep(0.1)  # 0.1 sec sampling

# ------------------------------------------------------------
# 3. FUNCTION TO RUN CPU MONITOR
# ------------------------------------------------------------
cpu_records = []

def cpu_monitor():
    global monitor_running
    while monitor_running:
        cpu_records.append({
            "cpu": psutil.cpu_percent(interval=0.1),
            "ram": psutil.virtual_memory().used / (1024**2),
        })

# ------------------------------------------------------------
# 4. RUN EXPERIMENT FOR EACH N
# ------------------------------------------------------------
rows = []

for N in N_values:
    print(f"\n===== Running N = {N} =====")

    gpu_records = []
    cpu_records = []
    monitor_running = True

    # Start monitoring threads
    t1 = threading.Thread(target=gpu_monitor)
    t2 = threading.Thread(target=cpu_monitor)
    t1.start()
    t2.start()

    # Run CUDA program (adjust if needed)
    cmd = ["./kmeans_cuda_prof", str(N), "16", "10", "200", "1e-4", "256", "0", "profile.csv"]
    start = time.time()
    subprocess.run(cmd)
    end = time.time()

    # Stop monitors
    monitor_running = False
    t1.join()
    t2.join()

    # Convert to DataFrames
    if len(gpu_records) == 0:
        print("Warning: GPU monitor captured no samples!")
        continue

    df_gpu = pd.DataFrame(gpu_records)
    df_cpu = pd.DataFrame(cpu_records)

    # Compute metrics
    gpu_avg = df_gpu["util_gpu"].mean()
    gpu_max = df_gpu["util_gpu"].max()
    mem_avg = df_gpu["mem_used"].mean()
    power_avg = df_gpu["power"].mean()

    cpu_avg = df_cpu["cpu"].mean()
    ram_avg = df_cpu["ram"].mean()

    # Add row
    rows.append({
        "N": N,
        "time_ms": (end - start) * 1000,
        "gpu_util_avg": gpu_avg,
        "gpu_util_max": gpu_max,
        "gpu_mem_avg_MB": mem_avg,
        "gpu_power_avg_W": power_avg,
        "cpu_util_avg": cpu_avg,
        "ram_used_avg_MB": ram_avg,
    })

# ------------------------------------------------------------
# 5. SAVE RESULTS
# ------------------------------------------------------------
df_final = pd.DataFrame(rows)
df_final.to_csv("nwise_monitoring.csv", index=False)

print("\nDONE! Saved N-wise metrics to nwise_monitoring.csv")
df_final
# Out:
# ===== Running N = 100 =====
#
# ===== Running N = 500 =====
#
# ===== Running N = 1000 =====
#
# ===== Running N = 5000 =====
#
# ===== Running N = 10000 =====
#
# ===== Running N = 20000 =====
#
# ===== Running N = 50000 =====
#
# ===== Running N = 100000 =====
#
# ===== Running N = 200000 =====
#
# ===== Running N = 300000 =====
#
# ===== Running N = 500000 =====
#
# ===== Running N = 1000000 =====
#
# ===== Running N = 2000000 =====
#
# DONE! Saved N-wise metrics to nwise_monitoring.csv
#           N      time_ms  gpu_util_avg  gpu_util_max  gpu_mem_avg_MB  \
# 0       100   190.271378      0.000000           0.0       10.000000
# 1       500   117.279530      0.000000           0.0        2.000000
# 2      1000   118.316889      5.000000           5.0        2.000000
# 3      5000   165.467262      5.000000           5.0       52.000000
# 4     10000   188.247919     16.000000          16.0       53.000000
# 5     20000   241.775990     10.500000          18.0       55.000000
# 6     50000   461.840630     41.000000          87.0       59.000000
# 7    100000   635.420322     35.166667          87.0       40.333333
# 8    200000  1020.901203     29.555556          82.0       46.222222
# 9    300000  1447.608709     23.250000          83.0       62.000000
# 10   500000  2319.000006     32.368421          85.0       70.105263
# 11  1000000  5008.626938     32.487179          89.0      105.692308
# 12  2000000  8825.943708     35.057143          94.0      166.885714
#
#     gpu_power_avg_W  cpu_util_avg  ram_used_avg_MB
# 0         15.005000     56.600000       862.498047
# 1         25.770000     33.950000       870.294922
# 2         25.770000     37.250000       870.078125
# 3         25.775000     54.100000       882.542969
# 4         25.825000     63.050000       873.318359
# 5         25.970000     48.266667       894.290365
# 6         28.527500     57.240000       910.171875
# 7         33.585000     55.728571       897.000558
# 8         40.105556     56.181818       905.813210
# 9         41.619167     58.360000       916.994271
# 10        42.020526     64.804167       935.046387
# 11        38.598205     74.022000       987.863281
# 12        38.516857     68.697727      1090.191806

# %%
import subprocess, time, psutil
import csv

Ns = [100,500,1000,5000,10000,20000,50000,100000,200000,300000,500000,1000000,2000000]

rows = []
for N in Ns:
    print(f"Running SERIAL for N={N}...")

    cpu_util = []
    ram_used = []

    # start serial program
    p = subprocess.Popen(
        ["./kmeans_cpu_serial", str(N), "16", "10", "200", "1e-4", "1", "0", "profile_cpu_serial.csv"],
        stdout=subprocess.PIPE, stderr=subprocess.PIPE
    )

    start = time.time()

    # monitor only CPU + RAM (no GPU here)
    while p.poll() is None:
        cpu_util.append(psutil.cpu_percent(interval=0.1))
        ram_used.append(psutil.virtual_memory().used / (1024*1024))

    end = time.time()

    time_ms = (end - start) * 1000

    rows.append([
        N, time_ms,
        sum(cpu_util)/len(cpu_util),
        sum(ram_used)/len(ram_used)
    ])

# save CPU monitoring file
with open("serial_monitoring.csv", "w", newline="") as f:
    w = csv.writer(f)
    w.writerow(["N","serial_time_ms","cpu_util_avg","ram_used_avg_MB"])
    w.writerows(rows)

print("DONE — saved serial_monitoring.csv")
# Out:
# Running SERIAL for N=100...
# Running SERIAL for N=500...
# Running SERIAL for N=1000...
# Running SERIAL for N=5000...
# Running SERIAL for N=10000...
# Running SERIAL for N=20000...
# Running SERIAL for N=50000...
# Running SERIAL for N=100000...
# Running SERIAL for N=200000...
# Running SERIAL for N=300000...
# Running SERIAL for N=500000...
# Running SERIAL for N=1000000...
# Running SERIAL for N=2000000...
# DONE — saved serial_monitoring.csv

# %%
# !nvcc -O3 -arch=sm_75 kmeans_cuda_prof.cu -o kmeans_cuda_prof
# !ls -lh kmeans_cuda_prof
# Out:
# -rwxr-xr-x 1 root root 1000K Nov 29 11:54 kmeans_cuda_prof

# %%
# !./kmeans_cuda_prof 200000 16 10 200 1e-4 256 1 profile_cuda.csv
# Out:
# Device 0: Tesla T4
#   CC 7.5  SMs=40  warpSize=32  maxThreadsPerBlock=1024  sharedMemPerBlock=48 KB
#   memory: 15.8 GB global, 0.1 MB const
# K-means CUDA: N=200000 D=16 K=10 max_iter=200 tol=0.0001 block=256 verbose=1
# Generating synthetic data on host...
# Init (kmeans++) on host...
# Launch config: grid=782 blocks, block=256 threads  (total threads 200192)
# Thread map sample (first up to 16 points): [i, blockIdx.x, threadIdx.x]
#   i=0  block=0  thread=0
#   i=1  block=0  thread=1
#   i=2  block=0  thread=2
#   i=3  block=0  thread=3
#   i=4  block=0  thread=4
#   i=5  block=0  thread=5
#   i=6  block=0  thread=6
#   i=7  block=0  thread=7
#   i=8  block=0  thread=8
#   i=9  block=0  thread=9
#   i=10  block=0  thread=10
#   i=11  block=0  thread=11
#   i=12  block=0  thread=12
#   i=13  block=0  thread=13
#   i=14  block=0  thread=14
#   i=15  block=0  thread=15
# Iter   1 | kernel(assign+accum)=3.945 ms, update=0.040 ms, inertia(sum)=1.279 ms | total=5.293 ms | move=89.6335
# Iter   2 | kernel(assign+accum)=3.719 ms, update=0.028 ms, inertia(sum)=0.456 ms | total=4.223 ms | move=0.773928
# Iter   3 | kernel(assign+accum)=3.793 ms, update=0.028 ms, inertia(sum)=0.463 ms | total=4.306 ms | move=0.237138
# Iter   4 | kernel(assign+accum)=3.735 ms, update=0.028 ms, inertia(sum)=0.464 ms | total=4.248 ms | move=0.105204
# Iter   5 | kernel(assign+accum)=3.741 ms, update=0.026 ms, inertia(sum)=0.456 ms | total=4.244 ms | move=0.0554189
# Iter   6 | kernel(assign+accum)=3.748 ms, update=0.027 ms, inertia(sum)=0.462 ms | total=4.257 ms | move=0.0318775
# Iter   7 | kernel(assign+accum)=3.717 ms, update=0.027 ms, inertia(sum)=0.495 ms | total=4.259 ms | move=0.0184311
# Iter   8 | kernel(assign+accum)=3.719 ms, update=0.028 ms, inertia(sum)=0.465 ms | total=4.233 ms | move=0.0119185
# Iter   9 | kernel(assign+accum)=3.791 ms, update=0.026 ms, inertia(sum)=0.453 ms | total=4.290 ms | move=0.00817563
# Iter  10 | kernel(assign+accum)=3.764 ms, update=0.026 ms, inertia(sum)=0.461 ms | total=4.273 ms | move=0.00679932
# Iter  11 | kernel(assign+accum)=3.762 ms, update=0.027 ms, inertia(sum)=0.461 ms | total=4.273 ms | move=0.00583827
# Iter  12 | kernel(assign+accum)=3.756 ms, update=0.026 ms, inertia(sum)=0.456 ms | total=4.257 ms | move=0.00509927
# Iter  13 | kernel(assign+accum)=3.731 ms, update=0.026 ms, inertia(sum)=0.471 ms | total=4.249 ms | move=0.00453655
# Iter  14 | kernel(assign+accum)=3.725 ms, update=0.026 ms, inertia(sum)=0.459 ms | total=4.228 ms | move=0.00416317
# Iter  15 | kernel(assign+accum)=3.744 ms, update=0.026 ms, inertia(sum)=0.458 ms | total=4.246 ms | move=0.00389391
# Iter  16 | kernel(assign+accum)=3.785 ms, update=0.028 ms, inertia(sum)=0.453 ms | total=4.286 ms | move=0.00361263
# Iter  17 | kernel(assign+accum)=3.807 ms, update=0.026 ms, inertia(sum)=0.460 ms | total=4.314 ms | move=0.0037219
# Iter  18 | kernel(assign+accum)=3.766 ms, update=0.027 ms, inertia(sum)=0.462 ms | total=4.276 ms | move=0.00369608
# Iter  19 | kernel(assign+accum)=3.737 ms, update=0.032 ms, inertia(sum)=0.455 ms | total=4.247 ms | move=0.0034954
# Iter  20 | kernel(assign+accum)=3.723 ms, update=0.028 ms, inertia(sum)=0.474 ms | total=4.245 ms | move=0.00344909
# Iter  21 | kernel(assign+accum)=3.748 ms, update=0.026 ms, inertia(sum)=0.457 ms | total=4.251 ms | move=0.00327956
# Iter  22 | kernel(assign+accum)=3.762 ms, update=0.026 ms, inertia(sum)=0.460 ms | total=4.269 ms | move=0.00316729
# Iter  23 | kernel(assign+accum)=3.713 ms, update=0.026 ms, inertia(sum)=0.450 ms | total=4.209 ms | move=0.00302333
# Iter  24 | kernel(assign+accum)=3.724 ms, update=0.029 ms, inertia(sum)=0.474 ms | total=4.248 ms | move=0.00303816
# Iter  25 | kernel(assign+accum)=3.766 ms, update=0.025 ms, inertia(sum)=0.462 ms | total=4.275 ms | move=0.00306033
# Iter  26 | kernel(assign+accum)=3.764 ms, update=0.027 ms, inertia(sum)=0.457 ms | total=4.268 ms | move=0.0028921
# Iter  27 | kernel(assign+accum)=3.744 ms, update=0.026 ms, inertia(sum)=0.459 ms | total=4.249 ms | move=0.00287266
# Iter  28 | kernel(assign+accum)=3.762 ms, update=0.027 ms, inertia(sum)=0.476 ms | total=4.286 ms | move=0.00325267
# Iter  29 | kernel(assign+accum)=3.750 ms, update=0.026 ms, inertia(sum)=0.475 ms | total=4.272 ms | move=0.00307846
# Iter  30 | kernel(assign+accum)=3.749 ms, update=0.028 ms, inertia(sum)=0.454 ms | total=4.252 ms | move=0.00302822
# Iter  31 | kernel(assign+accum)=3.764 ms, update=0.027 ms, inertia(sum)=0.458 ms | total=4.269 ms | move=0.00288337
# Iter  32 | kernel(assign+accum)=3.800 ms, update=0.028 ms, inertia(sum)=0.462 ms | total=4.309 ms | move=0.0027275
# Iter  33 | kernel(assign+accum)=3.887 ms, update=0.026 ms, inertia(sum)=0.459 ms | total=4.391 ms | move=0.00281164
# Iter  34 | kernel(assign+accum)=3.766 ms, update=0.026 ms, inertia(sum)=0.460 ms | total=4.273 ms | move=0.00265347
# Iter  35 | kernel(assign+accum)=3.746 ms, update=0.025 ms, inertia(sum)=0.463 ms | total=4.255 ms | move=0.00267933
# Iter  36 | kernel(assign+accum)=3.772 ms, update=0.026 ms, inertia(sum)=0.449 ms | total=4.268 ms | move=0.00265898
# Iter  37 | kernel(assign+accum)=3.767 ms, update=0.037 ms, inertia(sum)=0.508 ms | total=4.337 ms | move=0.00252573
# Iter  38 | kernel(assign+accum)=3.774 ms, update=0.042 ms, inertia(sum)=0.503 ms | total=4.347 ms | move=0.00270925
# Iter  39 | kernel(assign+accum)=3.746 ms, update=0.040 ms, inertia(sum)=0.479 ms | total=4.291 ms | move=0.00272964
# Iter  40 | kernel(assign+accum)=3.754 ms, update=0.037 ms, inertia(sum)=0.525 ms | total=4.359 ms | move=0.00292371
# Iter  41 | kernel(assign+accum)=3.752 ms, update=0.050 ms, inertia(sum)=0.600 ms | total=4.429 ms | move=0.00334404
# Iter  42 | kernel(assign+accum)=3.743 ms, update=0.047 ms, inertia(sum)=0.493 ms | total=4.309 ms | move=0.0033367
# Iter  43 | kernel(assign+accum)=3.392 ms, update=0.040 ms, inertia(sum)=0.489 ms | total=4.110 ms | move=0.00342568
# Iter  44 | kernel(assign+accum)=1.982 ms, update=0.036 ms, inertia(sum)=0.601 ms | total=2.652 ms | move=0.00341476
# Iter  45 | kernel(assign+accum)=1.980 ms, update=0.033 ms, inertia(sum)=0.496 ms | total=2.533 ms | move=0.00318752
# Iter  46 | kernel(assign+accum)=1.989 ms, update=0.030 ms, inertia(sum)=0.496 ms | total=2.536 ms | move=0.00322824
# Iter  47 | kernel(assign+accum)=2.030 ms, update=0.036 ms, inertia(sum)=0.527 ms | total=2.620 ms | move=0.00291187
# Iter  48 | kernel(assign+accum)=2.015 ms, update=0.038 ms, inertia(sum)=0.515 ms | total=2.594 ms | move=0.00284729
# Iter  49 | kernel(assign+accum)=1.979 ms, update=0.035 ms, inertia(sum)=0.506 ms | total=2.545 ms | move=0.0028813
# Iter  50 | kernel(assign+accum)=2.004 ms, update=0.038 ms, inertia(sum)=0.509 ms | total=2.575 ms | move=0.0026465
# Iter  51 | kernel(assign+accum)=2.028 ms, update=0.037 ms, inertia(sum)=0.485 ms | total=2.575 ms | move=0.00250754
# Iter  52 | kernel(assign+accum)=1.976 ms, update=0.036 ms, inertia(sum)=0.510 ms | total=2.548 ms | move=0.00226429
# Iter  53 | kernel(assign+accum)=1.988 ms, update=0.036 ms, inertia(sum)=0.474 ms | total=2.521 ms | move=0.00212813
# Iter  54 | kernel(assign+accum)=1.922 ms, update=0.037 ms, inertia(sum)=0.498 ms | total=2.728 ms | move=0.00206803
# Iter  55 | kernel(assign+accum)=2.025 ms, update=0.043 ms, inertia(sum)=0.533 ms | total=2.626 ms | move=0.00189001
# Iter  56 | kernel(assign+accum)=2.034 ms, update=0.036 ms, inertia(sum)=0.550 ms | total=2.645 ms | move=0.00195701
# Iter  57 | kernel(assign+accum)=2.027 ms, update=0.034 ms, inertia(sum)=0.505 ms | total=2.591 ms | move=0.00184775
# Iter  58 | kernel(assign+accum)=1.962 ms, update=0.035 ms, inertia(sum)=0.484 ms | total=2.507 ms | move=0.00158768
# Iter  59 | kernel(assign+accum)=1.933 ms, update=0.036 ms, inertia(sum)=0.478 ms | total=2.472 ms | move=0.00153545
# Iter  60 | kernel(assign+accum)=2.023 ms, update=0.036 ms, inertia(sum)=0.517 ms | total=2.603 ms | move=0.00151497
# Iter  61 | kernel(assign+accum)=1.936 ms, update=0.036 ms, inertia(sum)=0.488 ms | total=3.304 ms | move=0.00146797
# Iter  62 | kernel(assign+accum)=2.010 ms, update=0.042 ms, inertia(sum)=0.461 ms | total=2.539 ms | move=0.00126184
# Iter  63 | kernel(assign+accum)=1.978 ms, update=0.040 ms, inertia(sum)=0.558 ms | total=3.188 ms | move=0.00130222
# Iter  64 | kernel(assign+accum)=2.014 ms, update=0.038 ms, inertia(sum)=0.489 ms | total=2.567 ms | move=0.00137308
# Iter  65 | kernel(assign+accum)=2.014 ms, update=0.036 ms, inertia(sum)=0.498 ms | total=2.573 ms | move=0.0014441
# Iter  66 | kernel(assign+accum)=2.013 ms, update=0.036 ms, inertia(sum)=0.491 ms | total=2.565 ms | move=0.00133179
# Iter  67 | kernel(assign+accum)=2.042 ms, update=0.036 ms, inertia(sum)=0.505 ms | total=2.627 ms | move=0.00128532
# Iter  68 | kernel(assign+accum)=1.948 ms, update=0.049 ms, inertia(sum)=0.488 ms | total=2.526 ms | move=0.00133381
# Iter  69 | kernel(assign+accum)=1.987 ms, update=0.037 ms, inertia(sum)=0.483 ms | total=2.532 ms | move=0.00136472
# Iter  70 | kernel(assign+accum)=1.998 ms, update=0.030 ms, inertia(sum)=0.495 ms | total=2.547 ms | move=0.00136187
# Iter  71 | kernel(assign+accum)=1.921 ms, update=0.036 ms, inertia(sum)=0.498 ms | total=2.480 ms | move=0.00135849
# Iter  72 | kernel(assign+accum)=1.961 ms, update=0.036 ms, inertia(sum)=0.502 ms | total=2.525 ms | move=0.00133607
# Iter  73 | kernel(assign+accum)=2.053 ms, update=0.036 ms, inertia(sum)=0.503 ms | total=2.616 ms | move=0.00117556
# Iter  74 | kernel(assign+accum)=2.007 ms, update=0.042 ms, inertia(sum)=0.497 ms | total=2.781 ms | move=0.00109037
# Iter  75 | kernel(assign+accum)=2.017 ms, update=0.038 ms, inertia(sum)=0.550 ms | total=2.634 ms | move=0.000938907
# Iter  76 | kernel(assign+accum)=2.047 ms, update=0.037 ms, inertia(sum)=0.526 ms | total=2.637 ms | move=0.00101998
# Iter  77 | kernel(assign+accum)=1.949 ms, update=0.037 ms, inertia(sum)=0.487 ms | total=2.498 ms | move=0.000976479
# Iter  78 | kernel(assign+accum)=1.968 ms, update=0.034 ms, inertia(sum)=0.499 ms | total=2.523 ms | move=0.00115559
# Iter  79 | kernel(assign+accum)=1.964 ms, update=0.034 ms, inertia(sum)=0.490 ms | total=2.511 ms | move=0.00128513
# Iter  80 | kernel(assign+accum)=2.012 ms, update=0.037 ms, inertia(sum)=0.475 ms | total=2.550 ms | move=0.00133288
# Iter  81 | kernel(assign+accum)=1.972 ms, update=0.036 ms, inertia(sum)=0.462 ms | total=2.492 ms | move=0.00127499
# Iter  82 | kernel(assign+accum)=2.001 ms, update=0.037 ms, inertia(sum)=0.474 ms | total=2.536 ms | move=0.00128446
# Iter  83 | kernel(assign+accum)=1.931 ms, update=0.033 ms, inertia(sum)=0.487 ms | total=2.475 ms | move=0.00135167
# Iter  84 | kernel(assign+accum)=1.931 ms, update=0.036 ms, inertia(sum)=0.481 ms | total=2.474 ms | move=0.0013586
# Iter  85 | kernel(assign+accum)=1.993 ms, update=0.051 ms, inertia(sum)=0.463 ms | total=2.549 ms | move=0.0013841
# Iter  86 | kernel(assign+accum)=1.961 ms, update=0.036 ms, inertia(sum)=0.497 ms | total=2.520 ms | move=0.00143971
# Iter  87 | kernel(assign+accum)=2.009 ms, update=0.031 ms, inertia(sum)=0.464 ms | total=2.526 ms | move=0.00136699
# Iter  88 | kernel(assign+accum)=1.961 ms, update=0.030 ms, inertia(sum)=0.479 ms | total=2.490 ms | move=0.00135467
# Iter  89 | kernel(assign+accum)=1.999 ms, update=0.031 ms, inertia(sum)=0.463 ms | total=2.511 ms | move=0.00134824
# Iter  90 | kernel(assign+accum)=1.990 ms, update=0.039 ms, inertia(sum)=0.476 ms | total=2.523 ms | move=0.00146118
# Iter  91 | kernel(assign+accum)=1.993 ms, update=0.030 ms, inertia(sum)=0.478 ms | total=2.520 ms | move=0.00127892
# Iter  92 | kernel(assign+accum)=1.931 ms, update=0.030 ms, inertia(sum)=0.474 ms | total=2.455 ms | move=0.00121932
# Iter  93 | kernel(assign+accum)=1.939 ms, update=0.037 ms, inertia(sum)=0.516 ms | total=2.515 ms | move=0.00131393
# Iter  94 | kernel(assign+accum)=1.954 ms, update=0.037 ms, inertia(sum)=0.508 ms | total=2.971 ms | move=0.00148855
# Iter  95 | kernel(assign+accum)=1.936 ms, update=0.036 ms, inertia(sum)=0.499 ms | total=2.496 ms | move=0.00132253
# Iter  96 | kernel(assign+accum)=1.978 ms, update=0.038 ms, inertia(sum)=0.504 ms | total=2.547 ms | move=0.00129628
# Iter  97 | kernel(assign+accum)=2.007 ms, update=0.030 ms, inertia(sum)=0.461 ms | total=2.533 ms | move=0.00121681
# Iter  98 | kernel(assign+accum)=1.911 ms, update=0.027 ms, inertia(sum)=0.519 ms | total=2.475 ms | move=0.00103589
# Iter  99 | kernel(assign+accum)=1.947 ms, update=0.034 ms, inertia(sum)=0.459 ms | total=2.464 ms | move=0.00104387
# Iter 100 | kernel(assign+accum)=1.988 ms, update=0.031 ms, inertia(sum)=0.483 ms | total=2.522 ms | move=0.00103267
# Iter 101 | kernel(assign+accum)=1.916 ms, update=0.034 ms, inertia(sum)=0.518 ms | total=2.490 ms | move=0.00102183
# Iter 102 | kernel(assign+accum)=2.007 ms, update=0.036 ms, inertia(sum)=0.609 ms | total=2.677 ms | move=0.000987946
# Iter 103 | kernel(assign+accum)=1.993 ms, update=0.034 ms, inertia(sum)=0.474 ms | total=2.524 ms | move=0.000855978
# Iter 104 | kernel(assign+accum)=1.948 ms, update=0.031 ms, inertia(sum)=0.459 ms | total=2.458 ms | move=0.000874286
# Iter 105 | kernel(assign+accum)=1.961 ms, update=0.042 ms, inertia(sum)=0.466 ms | total=2.488 ms | move=0.000977495
# Iter 106 | kernel(assign+accum)=1.981 ms, update=0.031 ms, inertia(sum)=0.463 ms | total=2.495 ms | move=0.000864193
# Iter 107 | kernel(assign+accum)=2.005 ms, update=0.031 ms, inertia(sum)=0.475 ms | total=2.529 ms | move=0.000930848
# Iter 108 | kernel(assign+accum)=1.970 ms, update=0.030 ms, inertia(sum)=0.458 ms | total=2.483 ms | move=0.000854324
# Iter 109 | kernel(assign+accum)=1.962 ms, update=0.031 ms, inertia(sum)=0.488 ms | total=2.500 ms | move=0.000792367
# Iter 110 | kernel(assign+accum)=1.974 ms, update=0.030 ms, inertia(sum)=0.460 ms | total=2.484 ms | move=0.000756616
# Iter 111 | kernel(assign+accum)=1.938 ms, update=0.031 ms, inertia(sum)=0.485 ms | total=2.473 ms | move=0.00073099
# Iter 112 | kernel(assign+accum)=1.966 ms, update=0.031 ms, inertia(sum)=0.456 ms | total=2.472 ms | move=0.000811702
# Iter 113 | kernel(assign+accum)=1.989 ms, update=0.030 ms, inertia(sum)=0.478 ms | total=2.517 ms | move=0.00072405
# Iter 114 | kernel(assign+accum)=1.925 ms, update=0.030 ms, inertia(sum)=0.460 ms | total=2.434 ms | move=0.000717834
# Iter 115 | kernel(assign+accum)=1.918 ms, update=0.031 ms, inertia(sum)=0.500 ms | total=2.469 ms | move=0.000726302
# Iter 116 | kernel(assign+accum)=1.933 ms, update=0.037 ms, inertia(sum)=0.483 ms | total=2.476 ms | move=0.000803526
# Iter 117 | kernel(assign+accum)=1.962 ms, update=0.036 ms, inertia(sum)=0.502 ms | total=2.524 ms | move=0.000742534
# Iter 118 | kernel(assign+accum)=1.972 ms, update=0.038 ms, inertia(sum)=0.502 ms | total=2.538 ms | move=0.000798834
# Iter 119 | kernel(assign+accum)=1.894 ms, update=0.037 ms, inertia(sum)=0.511 ms | total=2.467 ms | move=0.000834068
# Iter 120 | kernel(assign+accum)=1.999 ms, update=0.036 ms, inertia(sum)=0.498 ms | total=2.558 ms | move=0.000892747
# Iter 121 | kernel(assign+accum)=1.578 ms, update=0.036 ms, inertia(sum)=0.493 ms | total=2.151 ms | move=0.000828064
# Iter 122 | kernel(assign+accum)=1.502 ms, update=0.031 ms, inertia(sum)=0.519 ms | total=2.074 ms | move=0.000776048
# Iter 123 | kernel(assign+accum)=1.532 ms, update=0.030 ms, inertia(sum)=0.503 ms | total=2.087 ms | move=0.000936273
# Iter 124 | kernel(assign+accum)=1.526 ms, update=0.029 ms, inertia(sum)=0.474 ms | total=2.048 ms | move=0.000879602
# Iter 125 | kernel(assign+accum)=1.536 ms, update=0.029 ms, inertia(sum)=0.468 ms | total=2.051 ms | move=0.000899062
# Iter 126 | kernel(assign+accum)=1.524 ms, update=0.030 ms, inertia(sum)=0.466 ms | total=2.040 ms | move=0.000909716
# Iter 127 | kernel(assign+accum)=1.585 ms, update=0.029 ms, inertia(sum)=0.464 ms | total=2.096 ms | move=0.000936608
# Iter 128 | kernel(assign+accum)=1.540 ms, update=0.029 ms, inertia(sum)=0.475 ms | total=2.063 ms | move=0.000849797
# Iter 129 | kernel(assign+accum)=1.511 ms, update=0.029 ms, inertia(sum)=0.464 ms | total=2.023 ms | move=0.000925684
# Iter 130 | kernel(assign+accum)=1.513 ms, update=0.029 ms, inertia(sum)=0.462 ms | total=2.022 ms | move=0.000891219
# Iter 131 | kernel(assign+accum)=1.526 ms, update=0.029 ms, inertia(sum)=0.461 ms | total=2.034 ms | move=0.0009316
# Iter 132 | kernel(assign+accum)=1.513 ms, update=0.029 ms, inertia(sum)=0.479 ms | total=2.041 ms | move=0.000961833
# Iter 133 | kernel(assign+accum)=1.502 ms, update=0.029 ms, inertia(sum)=0.478 ms | total=2.028 ms | move=0.000778584
# Iter 134 | kernel(assign+accum)=1.497 ms, update=0.029 ms, inertia(sum)=0.479 ms | total=2.024 ms | move=0.000882515
# Iter 135 | kernel(assign+accum)=1.500 ms, update=0.029 ms, inertia(sum)=0.487 ms | total=2.043 ms | move=0.000941647
# Iter 136 | kernel(assign+accum)=1.520 ms, update=0.028 ms, inertia(sum)=0.490 ms | total=2.056 ms | move=0.0010148
# Iter 137 | kernel(assign+accum)=1.494 ms, update=0.031 ms, inertia(sum)=0.483 ms | total=2.028 ms | move=0.00100464
# Iter 138 | kernel(assign+accum)=1.499 ms, update=0.029 ms, inertia(sum)=0.472 ms | total=2.020 ms | move=0.00101989
# Iter 139 | kernel(assign+accum)=1.508 ms, update=0.038 ms, inertia(sum)=0.469 ms | total=2.035 ms | move=0.00117315
# Iter 140 | kernel(assign+accum)=1.575 ms, update=0.030 ms, inertia(sum)=0.467 ms | total=2.091 ms | move=0.00106349
# Iter 141 | kernel(assign+accum)=1.498 ms, update=0.030 ms, inertia(sum)=0.466 ms | total=2.013 ms | move=0.000972676
# Iter 142 | kernel(assign+accum)=1.571 ms, update=0.029 ms, inertia(sum)=0.465 ms | total=2.085 ms | move=0.000966453
# Iter 143 | kernel(assign+accum)=1.548 ms, update=0.029 ms, inertia(sum)=0.464 ms | total=2.058 ms | move=0.000797384
# Iter 144 | kernel(assign+accum)=1.480 ms, update=0.029 ms, inertia(sum)=0.461 ms | total=1.990 ms | move=0.000804715
# Iter 145 | kernel(assign+accum)=1.530 ms, update=0.029 ms, inertia(sum)=0.465 ms | total=2.043 ms | move=0.000800346
# Iter 146 | kernel(assign+accum)=1.497 ms, update=0.030 ms, inertia(sum)=0.465 ms | total=2.012 ms | move=0.000738682
# Iter 147 | kernel(assign+accum)=1.536 ms, update=0.028 ms, inertia(sum)=0.520 ms | total=2.105 ms | move=0.000704418
# Iter 148 | kernel(assign+accum)=1.528 ms, update=0.029 ms, inertia(sum)=0.489 ms | total=2.067 ms | move=0.000640755
# Iter 149 | kernel(assign+accum)=1.553 ms, update=0.030 ms, inertia(sum)=0.482 ms | total=2.084 ms | move=0.000532401
# Iter 150 | kernel(assign+accum)=1.522 ms, update=0.029 ms, inertia(sum)=0.486 ms | total=2.055 ms | move=0.000546299
# Iter 151 | kernel(assign+accum)=1.501 ms, update=0.029 ms, inertia(sum)=0.478 ms | total=2.027 ms | move=0.000559418
# Iter 152 | kernel(assign+accum)=1.548 ms, update=0.036 ms, inertia(sum)=0.484 ms | total=2.091 ms | move=0.000616877
# Iter 153 | kernel(assign+accum)=1.535 ms, update=0.045 ms, inertia(sum)=0.485 ms | total=2.090 ms | move=0.000568941
# Iter 154 | kernel(assign+accum)=1.527 ms, update=0.036 ms, inertia(sum)=0.482 ms | total=2.070 ms | move=0.000539208
# Iter 155 | kernel(assign+accum)=1.543 ms, update=0.048 ms, inertia(sum)=0.486 ms | total=2.103 ms | move=0.000535171
# Iter 156 | kernel(assign+accum)=1.557 ms, update=0.035 ms, inertia(sum)=0.499 ms | total=2.117 ms | move=0.00047978
# Iter 157 | kernel(assign+accum)=1.589 ms, update=0.035 ms, inertia(sum)=0.499 ms | total=2.148 ms | move=0.00050739
# Iter 158 | kernel(assign+accum)=1.522 ms, update=0.027 ms, inertia(sum)=0.472 ms | total=2.044 ms | move=0.00039849
# Iter 159 | kernel(assign+accum)=1.550 ms, update=0.031 ms, inertia(sum)=0.553 ms | total=2.156 ms | move=0.000400108
# Iter 160 | kernel(assign+accum)=1.627 ms, update=0.034 ms, inertia(sum)=0.465 ms | total=2.150 ms | move=0.000445388
# Iter 161 | kernel(assign+accum)=1.512 ms, update=0.029 ms, inertia(sum)=0.464 ms | total=2.026 ms | move=0.00047818
# Iter 162 | kernel(assign+accum)=1.489 ms, update=0.035 ms, inertia(sum)=0.538 ms | total=2.082 ms | move=0.000490832
# Iter 163 | kernel(assign+accum)=1.526 ms, update=0.033 ms, inertia(sum)=0.482 ms | total=2.067 ms | move=0.000535023
# Iter 164 | kernel(assign+accum)=1.587 ms, update=0.038 ms, inertia(sum)=0.494 ms | total=2.198 ms | move=0.00048487
# Iter 165 | kernel(assign+accum)=1.501 ms, update=0.032 ms, inertia(sum)=2.516 ms | total=4.071 ms | move=0.000473771
# Iter 166 | kernel(assign+accum)=1.489 ms, update=0.035 ms, inertia(sum)=0.780 ms | total=2.329 ms | move=0.000458889
# Iter 167 | kernel(assign+accum)=1.532 ms, update=0.036 ms, inertia(sum)=0.492 ms | total=2.471 ms | move=0.000457722
# Iter 168 | kernel(assign+accum)=1.517 ms, update=0.033 ms, inertia(sum)=1.498 ms | total=3.074 ms | move=0.00044283
# Iter 169 | kernel(assign+accum)=1.541 ms, update=0.034 ms, inertia(sum)=0.853 ms | total=2.451 ms | move=0.000396403
# Iter 170 | kernel(assign+accum)=1.494 ms, update=0.035 ms, inertia(sum)=0.476 ms | total=2.235 ms | move=0.000349774
# Iter 171 | kernel(assign+accum)=1.599 ms, update=0.037 ms, inertia(sum)=0.501 ms | total=2.162 ms | move=0.000380967
# Iter 172 | kernel(assign+accum)=1.501 ms, update=0.037 ms, inertia(sum)=0.470 ms | total=2.033 ms | move=0.000383406
# Iter 173 | kernel(assign+accum)=1.556 ms, update=0.034 ms, inertia(sum)=0.799 ms | total=2.415 ms | move=0.00031107
# Iter 174 | kernel(assign+accum)=1.531 ms, update=0.050 ms, inertia(sum)=0.705 ms | total=2.351 ms | move=0.000365616
# Iter 175 | kernel(assign+accum)=1.502 ms, update=0.038 ms, inertia(sum)=0.497 ms | total=2.064 ms | move=0.000363778
# Iter 176 | kernel(assign+accum)=1.527 ms, update=0.031 ms, inertia(sum)=1.789 ms | total=3.370 ms | move=0.000288726
# Iter 177 | kernel(assign+accum)=1.489 ms, update=0.047 ms, inertia(sum)=0.489 ms | total=2.048 ms | move=0.000401202
# Iter 178 | kernel(assign+accum)=1.538 ms, update=0.032 ms, inertia(sum)=0.461 ms | total=2.054 ms | move=0.000431936
# Iter 179 | kernel(assign+accum)=1.493 ms, update=0.034 ms, inertia(sum)=0.483 ms | total=2.031 ms | move=0.000428501
# Iter 180 | kernel(assign+accum)=1.473 ms, update=0.033 ms, inertia(sum)=0.474 ms | total=2.001 ms | move=0.000503711
# Iter 181 | kernel(assign+accum)=1.538 ms, update=0.031 ms, inertia(sum)=0.458 ms | total=2.047 ms | move=0.000574545
# Iter 182 | kernel(assign+accum)=1.499 ms, update=0.034 ms, inertia(sum)=0.475 ms | total=2.032 ms | move=0.000562679
# Iter 183 | kernel(assign+accum)=1.529 ms, update=0.036 ms, inertia(sum)=0.471 ms | total=2.059 ms | move=0.000511144
# Iter 184 | kernel(assign+accum)=1.541 ms, update=0.030 ms, inertia(sum)=0.485 ms | total=2.077 ms | move=0.000554807
# Iter 185 | kernel(assign+accum)=1.565 ms, update=0.034 ms, inertia(sum)=0.465 ms | total=2.089 ms | move=0.000521959
# Iter 186 | kernel(assign+accum)=1.563 ms, update=0.033 ms, inertia(sum)=0.496 ms | total=2.114 ms | move=0.000486242
# Iter 187 | kernel(assign+accum)=1.495 ms, update=0.032 ms, inertia(sum)=0.459 ms | total=2.009 ms | move=0.000526083
# Iter 188 | kernel(assign+accum)=1.537 ms, update=0.036 ms, inertia(sum)=0.455 ms | total=2.049 ms | move=0.000566113
# Iter 189 | kernel(assign+accum)=1.477 ms, update=0.033 ms, inertia(sum)=0.457 ms | total=1.988 ms | move=0.000598484
# Iter 190 | kernel(assign+accum)=1.531 ms, update=0.034 ms, inertia(sum)=0.485 ms | total=2.070 ms | move=0.000570565
# Iter 191 | kernel(assign+accum)=1.518 ms, update=0.034 ms, inertia(sum)=0.505 ms | total=2.080 ms | move=0.00048868
# Iter 192 | kernel(assign+accum)=1.535 ms, update=0.034 ms, inertia(sum)=0.502 ms | total=2.094 ms | move=0.000442695
# Iter 193 | kernel(assign+accum)=1.536 ms, update=0.034 ms, inertia(sum)=0.479 ms | total=2.073 ms | move=0.000500489
# Iter 194 | kernel(assign+accum)=1.534 ms, update=0.163 ms, inertia(sum)=0.466 ms | total=2.187 ms | move=0.000520653
# Iter 195 | kernel(assign+accum)=1.479 ms, update=0.034 ms, inertia(sum)=0.471 ms | total=2.007 ms | move=0.00059119
# Iter 196 | kernel(assign+accum)=1.542 ms, update=0.033 ms, inertia(sum)=0.466 ms | total=2.064 ms | move=0.000586567
# Iter 197 | kernel(assign+accum)=1.480 ms, update=0.030 ms, inertia(sum)=0.464 ms | total=1.995 ms | move=0.000500197
# Iter 198 | kernel(assign+accum)=1.565 ms, update=0.031 ms, inertia(sum)=0.457 ms | total=2.073 ms | move=0.000402118
# Iter 199 | kernel(assign+accum)=1.470 ms, update=0.029 ms, inertia(sum)=0.454 ms | total=1.972 ms | move=0.000406988
# Iter 200 | kernel(assign+accum)=1.569 ms, update=0.029 ms, inertia(sum)=0.456 ms | total=2.072 ms | move=0.000361637
# Total wall time: 561.72 ms  (includes H2D/D2H where applicable)
# Profile saved to profile_cuda.csv

# %%
# Visualization for CUDA run (reads labels_cuda.csv, centroids_cuda.csv, meta_cuda.txt)
import os, math, numpy as np, matplotlib.pyplot as plt, imageio
from matplotlib import colormaps

def load_meta(path="meta_cuda.txt"):
    vals={}
    with open(path,'r') as f:
        for ln in f:
            parts=ln.strip().split()
            if len(parts)==2:
                vals[parts[0]]=int(parts[1])
    return vals['N'], vals['D'], vals['K']

def safe_load_centroids(path):
    return np.loadtxt(path, dtype=float, ndmin=2, delimiter=',')

# RNG to reproduce exact C synthetic set
class XorShift64Star:
    def __init__(self, seed=88172645463325252):
        self.state = seed & ((1<<64)-1)
    def next_u64(self):
        x = self.state
        x ^= (x >> 12) & ((1<<64)-1)
        x ^= (x << 25) & ((1<<64)-1)
        x ^= (x >> 27) & ((1<<64)-1)
        self.state = x & ((1<<64)-1)
        return (x * 2685821657736338717) & ((1<<64)-1)
    def drand01(self):
        u = self.next_u64()
        v = (u >> 11) & ((1<<53)-1)
        return v * (1.0/9007199254740992.0)

def generate_synthetic_same(N, D, K, seed=88172645463325252):
    rng = XorShift64Star(seed)
    centers = np.zeros((K, D), dtype=np.float64)
    for k in range(K):
        for d in range(D):
            centers[k, d] = (rng.drand01() * 2.0 - 1.0) * 10.0
    data = np.zeros((N, D), dtype=np.float64)
    for i in range(N):
        c = i % K
        for d in range(D):
            u1 = rng.drand01()
            u2 = rng.drand01()
            r = math.sqrt(-2.0 * math.log(max(u1, 1e-12)))
            z = r * math.cos(2.0 * math.pi * u2)
            scale = 1.0 + 0.5 * rng.drand01()
            data[i, d] = centers[c, d] + z * scale
    return data

def pca_project_2d(X):
    Xc = X - np.mean(X, axis=0, keepdims=True)
    C = (Xc.T @ Xc) / (Xc.shape[0]-1)
    vals, vecs = np.linalg.eigh(C)
    order = np.argsort(vals)[::-1]
    top2 = vecs[:, order[:2]]
    proj = Xc @ top2
    return proj, top2, Xc.mean(axis=0, keepdims=True)

# --- load outputs ---
if not (os.path.exists("labels_cuda.csv") and os.path.exists("centroids_cuda.csv") and os.path.exists("meta_cuda.txt")):
    raise FileNotFoundError("Missing CUDA outputs. Run the CUDA binary first.")

N,D,K = load_meta("meta_cuda.txt")
labels = np.loadtxt("labels_cuda.csv", dtype=int, ndmin=1)
centroids = safe_load_centroids("centroids_cuda.csv")
assert labels.shape[0]==N, "labels size mismatch with meta"

# regenerate data exactly
data = generate_synthetic_same(N,D,K)

# project to 2D for plot
if D==2:
    coords = data.copy()
    cent2 = centroids.copy()
    xlabel, ylabel = "x","y"
else:
    coords, basis, mean0 = pca_project_2d(data)
    cent2 = (centroids - mean0) @ basis
    xlabel, ylabel = "PC 1","PC 2"

# plotting (uniform size)
os.makedirs("outputs", exist_ok=True)
cmap = colormaps.get_cmap('tab20')
colors = [cmap(i % cmap.N) for i in range(K)]

def save_plot(path, zoom=False):
    plt.figure(figsize=(10,8))
    if zoom:
        pad=0.05
        xmin,xmax = coords[:,0].min(), coords[:,0].max()
        ymin,ymax = coords[:,1].min(), coords[:,1].max()
        dx,dy=(xmax-xmin),(ymax-ymin)
        if dx==0: dx=1.0
        if dy==0: dy=1.0
        plt.xlim(xmin-pad*dx, xmax+pad*dx)
        plt.ylim(ymin-pad*dy, ymax+pad*dy)

    for k in range(K):
        m = (labels==k)
        pts = coords[m]
        if pts.size>0:
            plt.scatter(pts[:,0], pts[:,1], s=8, color=colors[k], alpha=0.6, label=f"C{k}")
    plt.scatter(cent2[:,0], cent2[:,1], s=180, color='black', marker='X', label='Centroids')
    for k in range(K):
        plt.text(cent2[k,0], cent2[k,1], f" {k}", color='white', fontsize=9,
                 bbox=dict(facecolor='black', alpha=0.7, boxstyle='round,pad=0.2'))
    plt.title(f"K-means (CUDA): N={N}, D={D}, K={K}")
    plt.xlabel(xlabel); plt.ylabel(ylabel)
    plt.legend(markerscale=2, fontsize='small', ncol=2)
    plt.tight_layout()
    plt.savefig(path, dpi=200); plt.close()
    plt.show()
full_png = "outputs/kmeans_cuda_viz.png"
zoom_png = "outputs/kmeans_cuda_viz_zoom.png"
save_plot(full_png, zoom=False)
save_plot(zoom_png, zoom=True)
print("Saved", full_png, "and", zoom_png)

# build a small GIF (same size frames)
frames = [imageio.imread(full_png), imageio.imread(zoom_png)]
imageio.mimsave("outputs/kmeans_cuda_viz.gif", frames, duration=1.0)
print("Saved outputs/kmeans_cuda_viz.gif")

# peek a few coords
print("Sample:", [(int(i), int(labels[i]), np.round(coords[i,:],3).tolist()) for i in range(min(5,N))])
# Out:
# Saved outputs/kmeans_cuda_viz.png and outputs/kmeans_cuda_viz_zoom.png
# /tmp/ipython-input-789954753.py:121: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   frames = [imageio.imread(full_png), imageio.imread(zoom_png)]
# Saved outputs/kmeans_cuda_viz.gif
# Sample: [(0, 8, [-9.834, 11.104]), (1, 2, [17.624, -4.989]), (2, 3, [0.112, 14.536]), (3, 0, [-11.953, -8.056]), (4, 8, [-1.123, 4.02])]
